# %% [markdown]
# <a href="https://colab.research.google.com/github/uvais-hub/genai-challenge/blob/main/python-beginner/myfirstpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
x = "x"
apple = "apple"
x not in apple
# Out:
# True
